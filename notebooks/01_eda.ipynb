# %% [markdown]
# # 01 — EDA энергопотребления
#
# Цель: загрузить данные, проверить качество, посчитать базовые статистики и сделать выводы.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('../data/raw/sample_load.csv', parse_dates=['timestamp'])
df.head()

# %% [markdown]
# ## 1. Проверка данных
# Заполни раздел самостоятельно.

# %%
# df.shape
# df.info()
# df.describe()

# %% [markdown]
# ## 2. Описательная статистика

# %%
# TODO: mean, median, std, quantiles

# %% [markdown]
# ## 3. Визуализация

# %%
# TODO: line plot, histogram, scatter plot

# %% [markdown]
# ## 4. Выводы
# Напиши минимум 5 содержательных выводов.
